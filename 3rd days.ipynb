# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
file_path = r'C:\Users\Osama\OneDrive\Desktop\BrainyBeam\archive\gdp.csv' # replace with your actual file path
data = pd.read_csv(file_path)

# %%
print(data.head())
# Out:
#                   Country Name Code          1960          1961          1962  \
# 0                        Aruba  ABW           NaN           NaN           NaN
# 1  Africa Eastern and Southern  AFE  1.931311e+10  1.972349e+10  2.149392e+10
# 2                  Afghanistan  AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 3   Africa Western and Central  AFW  1.040428e+10  1.112805e+10  1.194335e+10
# 4                       Angola  AGO           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  2.573321e+10  2.352744e+10  2.681057e+10  2.915216e+10  3.017317e+10  ...
# 2  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 3  1.267652e+10  1.383858e+10  1.486247e+10  1.583285e+10  1.442643e+10  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
# ...

# %%
data.iloc[25]
# Out:
# Country Name               Belarus
# Code                           BLR
# 1960                           NaN
# 1961                           NaN
# 1962                           NaN
#                        ...
# 2017            54726595249.184898
# 2018            60031262269.336502
# 2019            64409647193.804398
# 2020            60258239055.582901
# Unnamed: 65                    NaN
# Name: 25, Length: 64, dtype: object

# %%
data.loc[100,"Country Name"]
# Out:
# 'Haiti'

# %%
data.iloc[100:200:5,[1,5,9,10,0]]
# Out:
#     Code          1963          1967          1968  \
# 100  HTI  2.948834e+08  3.691242e+08  3.679688e+08
# 105  IDB  1.461190e+10  1.893035e+10  1.998231e+10
# 110  INX           NaN           NaN           NaN
# 115  ISR  2.992333e+09  4.030000e+09  4.619000e+09
# 120  KAZ           NaN           NaN           NaN
# 125  KNA  1.283323e+07  1.674234e+07  1.460000e+07
# 130  LBN           NaN           NaN           NaN
# 135  LDC           NaN           NaN           NaN
# 140  LMY  3.617016e+11  4.759601e+11  5.024285e+11
# 145  LVA           NaN           NaN           NaN
# 150  MDA           NaN           NaN           NaN
# 155  MHL           NaN           NaN           NaN
# 160  MMR  6.599767e+08  3.281824e+08  5.311864e+08
# 165  MOZ           NaN           NaN           NaN
# 170  NAC  6.837264e+11  9.275238e+11  1.014480e+12
# 175  NIC  2.929162e+08  6.571714e+08  6.959000e+08
# 180  NZL  6.638937e+09  5.961418e+09  5.180598e+09
# ...
